# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import pandas as pd 
import seaborn as sns

import itertools

import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX

from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ### Задание №1

# %% [markdown]
# Прочитайте базу my_PJME_MW.csv и сделайте ее перерасчет (ресемплинг) в представление по неделям.

# %%
data = pd.read_csv('my_PJME_MW.csv', index_col=[0], parse_dates=[0])
data.head()
# Out:
#                 Time  PJME_MW  year  month  dayofmonth  quarter  dayofyear  \
# Date
# 2002-01-01  01:00:00  30393.0  2002      1           1        1          1
# 2002-01-01  02:00:00  29265.0  2002      1           1        1          1
# 2002-01-01  03:00:00  28357.0  2002      1           1        1          1
# 2002-01-01  04:00:00  27899.0  2002      1           1        1          1
# 2002-01-01  05:00:00  28057.0  2002      1           1        1          1
#
#             weekofyear  dayofweek  hour  is_holiday  is_prev_holiday  \
# Date
# 2002-01-01           1          1     1           1                0
# 2002-01-01           1          1     2           1                0
# 2002-01-01           1          1     3           1                0
# 2002-01-01           1          1     4           1                0
# 2002-01-01           1          1     5           1                0
#
#             is_next_holiday
# Date
# 2002-01-01                0
# 2002-01-01                0
# 2002-01-01                0
# 2002-01-01                0
# 2002-01-01                0

# %%
data_w = data.resample('W').mean()
data_w.tail()
# Out:
#                  PJME_MW    year     month  dayofmonth  quarter   dayofyear  \
# Date
# 2018-07-08  38459.982143  2018.0  7.000000    5.000000      3.0  186.000000
# 2018-07-15  36420.035714  2018.0  7.000000   12.000000      3.0  193.000000
# 2018-07-22  35612.095238  2018.0  7.000000   19.000000      3.0  200.000000
# 2018-07-29  36581.821429  2018.0  7.000000   26.000000      3.0  207.000000
# 2018-08-05  36568.804124  2018.0  7.505155   15.865979      3.0  212.525773
#
#             weekofyear  dayofweek       hour  is_holiday  is_prev_holiday  \
# Date
# 2018-07-08        27.0   3.000000  11.500000    0.142857         0.142857
# 2018-07-15        28.0   3.000000  11.500000    0.000000         0.000000
# 2018-07-22        29.0   3.000000  11.500000    0.000000         0.000000
# 2018-07-29        30.0   3.000000  11.500000    0.000000         0.000000
# 2018-08-05        31.0   1.525773  11.381443    0.000000         0.000000
#
#             is_next_holiday
# Date
# 2018-07-08         0.142857
# 2018-07-15         0.000000
# 2018-07-22         0.000000
# 2018-07-29         0.000000
# 2018-08-05         0.000000

# %%
plt.figure(figsize =(15, 6))
plt.plot( data_w.index, data_w['PJME_MW'].values)
plt.title('PJM East еженедельное потребление энергии')
plt.ylabel ('МВт');

# %%
# %%time 

p = range(2, 10)
d = range(2, 10)
q = range(2, 10)

# зададим сетку p, d и q
pdq = list(itertools.product(p, d, q))

for param in pdq:
    try:
        mod = sm.tsa.statespace.SARIMAX(data_w['PJME_MW'].values[:-30],
                                order=param,
                                seasonal_order=[1, 1, 2, 26],
                                enforce_stationarity=False,
                                enforce_invertibility=False)
        aic_ = 1000000
        param_ = None 
        param_seasonal_ = None
        results = mod.fit()
        if results.aic < aic_:
            aic_ = results.aic
            param_ = param 
            param_seasonal_ = param_seasonal
    except:
        continue
print('SARIMAX {} x {} - AIC: {}'.format(param_, param_seasonal_, aic_))
# Out:
# SARIMAX (9, 9, 9) x None - AIC: 18551.97277671262
# CPU times: user 3d 14h 39min 38s, sys: 6min 36s, total: 3d 14h 46min 15s
# Wall time: 21h 43min 5s

# %%
data_w['w_m'] = data_w['PJME_MW'].rolling(window=4).mean()

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] 
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

data_w['exp_0_5'] = exponential_smoothing(data_w['PJME_MW'], 0.5)

# %%
p = 8
for i in range(p):
    data_w['t'+str(p-i)]=0
    data_w['t'+str(p-i)].values[p:] = data_w['PJME_MW'].values[i:-(p)+i]

# %%
p = 8
first_diff = data_w.iloc[1:, 0].values - data_w.iloc[:-1, 0].values 
data_w['diff1'] = 0
data_w['diff1'].values[1:] = first_diff

for i in range(p):
    data_w['d'+str(p-i)] = 0
    data_w['d'+str(p-i)].values[p:] = data_w['diff1'].values[i:-(p)+i]

# %%
data_w.head()
# Out:
#                  PJME_MW    year     month  dayofmonth  quarter  dayofyear  \
# Date
# 2002-01-06  32392.160839  2002.0  1.000000    3.517483      1.0   3.517483
# 2002-01-13  31487.386905  2002.0  1.000000   10.000000      1.0  10.000000
# 2002-01-20  31452.880952  2002.0  1.000000   17.000000      1.0  17.000000
# 2002-01-27  30141.529762  2002.0  1.000000   24.000000      1.0  24.000000
# 2002-02-03  29196.488095  2002.0  1.428571   17.714286      1.0  31.000000
#
#             weekofyear  dayofweek      hour  is_holiday ...  d7  t8  diff1  \
# Date                                                    ...
# 2002-01-06         1.0   3.517483  11.58042    0.160839 ...   0   0      0
# 2002-01-13         2.0   3.000000  11.50000    0.000000 ...   0   0   -904
# 2002-01-20         3.0   3.000000  11.50000    0.000000 ...   0   0    -34
# 2002-01-27         4.0   3.000000  11.50000    0.142857 ...   0   0  -1311
# 2002-02-03         5.0   3.000000  11.50000    0.000000 ...   0   0   -945
#
#             d8  d6  d5  d4  d3  d2  d1
# Date
# 2002-01-06   0   0   0   0   0   0   0
# 2002-01-13   0   0   0   0   0   0   0
# 2002-01-20   0   0   0   0   0   0   0
# 2002-01-27   0   0   0   0   0   0   0
# 2002-02-03   0   0   0   0   0   0   0
#
# [5 rows x 31 columns]

# %%
data_w.columns
# Out:
# Index(['PJME_MW', 'year', 'month', 'dayofmonth', 'quarter', 'dayofyear',
#        'weekofyear', 'dayofweek', 'hour', 'is_holiday', 'is_prev_holiday',
#        'is_next_holiday', 'w_m', 'exp_0_5', 't7', 't6', 't5', 't4', 't3', 't2',
#        't1', 'd7', 't8', 'diff1', 'd8', 'd6', 'd5', 'd4', 'd3', 'd2', 'd1'],
#       dtype='object')

# %%
data_w = data_w[['PJME_MW', 'dayofyear',
       'weekofyear', 'is_holiday', 'is_prev_holiday',
       'is_next_holiday', 'exp_0_5', 't8', 't7', 't6', 't5', 't4', 't3', 't2',
       't1', 'd7', 'diff1', 'd8', 'd7', 'd6', 'd5', 'd4', 'd3', 'd2', 'd1']]

# %%
def split_data(data, split_date):
    return data.loc[data.index.get_level_values('Date') <= split_date].copy(), data.loc[data.index.get_level_values('Date') >  split_date].copy()

# %%
train, test = split_data(data_w, '2016-01-01')

plt.figure(figsize=( 15, 7 ))
plt.xlabel('Время')
plt.ylabel('Потребление энергии, МВт')
plt.plot(train.index.get_level_values('Date'),train['PJME_MW'], label='Тренировочные данные' )
plt.plot(test.index.get_level_values('Date'),test['PJME_MW'], label='Тестовые данные')
plt.title( 'Тестовые и тренировочные данные' )
plt.legend()
plt.show()

# %% [markdown]
# ### Задание №2

# %% [markdown]
# Постройте модель предсказания 4-й точки от текущей (h = 4), используя результаты моделирования ARIMA (смотрим на порядок моделей и порядок сезонности и формируем признаки соответствующего вида (порядой интегрирования d=1 - нужна первая разность, p = 10 - берем глубину истории 10)).

# %%
h = 4

# %%
X_train_4 = train.iloc[:-h,:]

# %%
y_train_4 = train[data_w.columns[0]].values[:-h]

# %%
X_test_4 = test.iloc[:-h,:]

# %%
y_test_4 = test[data_w.columns[0]].values[:-h]

# %%
model_gb = GradientBoostingRegressor(max_depth=3, random_state=0, n_estimators=100)

model_gb.fit(X_train_4, y_train_4) 
X_test_pred_gb_4 = model_gb.predict(X_test_4)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
plt.figure( figsize=(16, 6))

plt.xlabel('Время')
plt.ylabel('Потребление энергии')
plt.plot(test.index[h: h + 50], X_test_pred_gb_4[: 50], label='Предсказание')
plt.plot(test.index[h: h + 50], y_test_4[: 50], label='Тестовые данные')
plt.legend()
plt.show()

er_g_4 = mean_absolute_percentage_error(y_true=y_test_4, y_pred=X_test_pred_gb_4)

print('Ошибка градиентного бустинга :  ', er_g_4, '%')
# Out:
# Ошибка градиентного бустинга :   0.17800661834772522 %

# %% [markdown]
# ### Задание №3

# %% [markdown]
# Постройте модель предсказания 1-й точки от текущей (h = 1), используя результаты моделирования ARIMA (смотрим на порядок моделей и порядок сезонности).

# %%
h = 1

# %%
X_train_1 = train.iloc[:-h,:]

# %%
y_train_1 = train[data_w.columns[0]].values[:-h]

# %%
X_test_1 = test.iloc[:-h,:]

# %%
y_test_1 = test[data_w.columns[0]].values[:-h]

# %%
model_gb = GradientBoostingRegressor(max_depth=3, random_state=0, n_estimators=100)

model_gb.fit(X_train_1, y_train_1) 
X_test_pred_gb_1 = model_gb.predict(X_test_1)

# %%
plt.figure( figsize=(16, 6))

plt.xlabel('Время')
plt.ylabel('Потребление энергии')
plt.plot(test.index[h: h + 50], X_test_pred_gb_1[: 50], label='Предсказание')
plt.plot(test.index[h: h + 50], y_test_4[: 50], label='Тестовые данные')
plt.legend()
plt.show()

er_g_1 = mean_absolute_percentage_error(y_true=y_test_1, y_pred=X_test_pred_gb_1)

print('Ошибка градиентного бустинга :  ', er_g_1, '%')
# Out:
# Ошибка градиентного бустинга :   0.1812344851148806 %

# %% [markdown]
# ### Задание №4

# %% [markdown]
# Примените авторекурсию и сравните результат в 4-й точке путем прямого моделирования и путем рекурсивного моделирования на длине выборки bp 4-х точек.

# %%
cols = len(data_w.columns)

X_test_rec = X_test_4.copy()
y_test_rec = X_test_pred_gb_4.copy()

N = 4
for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]

# %%
plt.figure( figsize=( 15, 7 ))


plt.xlabel('Время')
plt.ylabel('Потребление энергии, МВт')
plt.plot(test.index[1: N+1], X_test_pred_gb_4[:N], 'r', label='Предсказание путем прямого моделирования' )
plt.plot(test.index[1: N+1], y_test_4[:N], 'g', label='Тестовые данные', alpha=0.5)
plt.plot(test.index[1: N+1], y_test_rec[:N], '--r', label='Предсказание путем рекурсивного моделирования')

plt.legend()
plt.show()

# %%
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])

print('Ошибка градиентного бустинга:  ', er_g_4, '%')
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка градиентного бустинга:   0.17800661834772522 %
# Ошибка рекурсивного моделирования:   11.684119340524502 %

# %% [markdown]
# ### Задание №5

# %% [markdown]
# Оцените рост ошибки прогнозирования рекурсивной модели в интервалах от 1-й до 10-й, от 10-й до 20-й, от 20-й до 30-й, .. .10i-й до (i+1)10 -й,... ,от 90 до 100-й точках (используйте осреденение по десяткам точек)

# %%
N = 10

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   10.783963489576893 %

# %%
N = 20

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   9.622156207023586 %

# %%
N = 30

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.615607956024188 %

# %%
N = 40

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   13.76073944232174 %

# %%
N = 50

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   12.115709220188458 %

# %%
N = 60

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.958669239619773 %

# %%
N = 70

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.18899230955241 %

# %%
N = 80

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.269208317066148 %

# %%
N = 90

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.6602976325531 %

# %%
N = 100

for i in range(N):
    y_test_rec[i] = model_gb.predict(X_test_rec.iloc[i, :].values.reshape((1, -1)))
    X_test_rec.iloc[i + 1, 0] = y_test_rec[i]
    
er_g_rec = mean_absolute_percentage_error(y_true=y_test_4[:N], y_pred=y_test_rec[:N])
print('Ошибка рекурсивного моделирования:  ', er_g_rec, '%')
# Out:
# Ошибка рекурсивного моделирования:   11.051226432747086 %
